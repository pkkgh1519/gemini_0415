# %% [markdown]
# # Google Gemini Agent 개발 기본

# %% [markdown]
# ### Geminy API 호출 방식

# %%
#  Gemini 네이티브 방식
from google import genai

client = genai.Client(vertexai=True, project="byounghwa-go", location="global")
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="LLM을 사용한 Agent는 무엇인가요? 간단히 요약해주세요"
)
print(response.text)
# Out:
# LLM을 사용한 에이전트(Agent)는 **LLM(대규모 언어 모델)을 '뇌'처럼 활용하여 복잡한 목표를 스스로 계획하고 실행하며 달성하는 인공지능 시스템**입니다.
#
# 간단히 요약하자면:
#
# 1.  **뇌(Brain):** LLM이 문제 이해, 계획 수립, 추론, 의사결정 등을 담당합니다.
# 2.  **도구(Tools):** LLM은 웹 검색, 계산기, API 호출, 코드 실행 등 외부 도구를 사용하여 정보를 얻거나 실제 행동을 수행할 수 있습니다.
# 3.  **기억(Memory):** 이전 대화, 행동 결과, 학습 내용을 기억하여 다음 행동에 반영하고, 여러 단계를 거쳐 목표를 달성합니다.
# 4.  **자율성(Autonomy):** 주어진 목표를 향해 스스로 계획을 세우고, 실행하고, 결과를 평가하며, 필요에 따라 계획을 수정하는 반복적인 과정을 거쳐 최종 목표에 도달합니다.
#
# 마치 **똑똑한 비서나 전문 작업자**처럼, 단순히 질문에 답하는 것을 넘어 **여러 단계를 거쳐 복잡한 임무를 능동적으로 완수**하는 AI라고 할 수 있습니다.

# %%
# OpenAI 호환성 방식
# !pip install openai
from openai import OpenAI

client = OpenAI(    
    api_key="<API Key>",   # Google AI Studio에서 발급받은 Gemini API Key로 수정한다
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=[
        {"role": "user", "content": "LLM은 어떻게 작동하나요? 2줄로 요약해줘"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Collecting openai
#   Downloading openai-2.31.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.10/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/conda/lib/python3.10/site-packages (from openai) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Downloading openai-2.31.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.0 MB/s  0:00:00
# Downloading jiter-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (358 kB)
# Installing collected packages: jiter, openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openai]2m1/2 [openai]
# Successfully installed jiter-0.14.0 openai-2.31.0
# LLM은 방대한 텍스트 데이터를 학습하여 언어의 패턴과 단어 간 관계를 파악합니다. 이를 바탕으로 주어진 문맥에 가장 적합한 다음 단어를 예측하며 문장을 생성하는 방식으로 작동합니다.

# %% [markdown]
# #### 시스템 지시사항 및 파라미터 설정

# %%
# system_instruction 으로 페르소나(Persona) 설정
from google.genai import types
from google import genai

client = genai.Client(vertexai=True, project="byounghwa-go", location="global")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=types.GenerateContentConfig(
        system_instruction="당신은 초등학교 과학 선생님입니다",
    ),
    contents="하늘이 파란 이유를 간단히 설명해줘"
)
print(response.text)
# Out:
# 친구들! 하늘이 왜 파란지 궁금했죠? 우리 눈에 보이지 않는 아주 작은 것들이 하늘에서 특별한 마법을 부리기 때문이에요. 선생님이 쉽게 설명해 줄게요!
#
# 1.  **햇빛은 무지개 색깔이야!**
#     *   우리 눈에는 햇빛이 하얀색처럼 보이지만, 사실 빨주노초파남보 무지개처럼 여러 가지 색깔 빛이 섞여 있는 거예요. 이 색깔 빛들은 저마다 '크기'가 조금씩 다르답니다. 파란색 빛은 작고 날렵하고, 빨간색 빛은 크고 묵직하다고 생각하면 쉬워요.
#
# 2.  **하늘에는 아주 작은 공기 알갱이들이 가득해!**
#     *   우리 눈에는 안 보이지만, 하늘에는 공기 알갱이(산소, 질소 같은 작은 입자들)들이 아주 많이 떠다니고 있어요. 마치 아주 작은 먼지 알갱이들처럼 말이죠.
#
# 3.  **파란색 빛이 공기 알갱이랑 잘 부딪혀!**
#     *   자, 이제 햇빛이 이 작은 공기 알갱이들을 통과할 때 어떤 일이 벌어질까요?
#     *   작고 날렵한 **파란색 빛**은 이 작은 공기 알갱이들과 잘 부딪혀서 사방팔방으로 튕겨 나가요! 마치 아주 작은 공이 수많은 탁구공 사이를 지나가면 이리저리 부딪혀서 여기저기 튀어 오르는 것과 같아요.
#     *   하지만 크고 묵직한 **빨간색이나 노란색 빛**은 공기 알갱이들과 잘 부딪히지 않고 그냥 쭉~ 지나가려고 해요.
#
# 4.  **그래서 우리가 파란색을 보는 거야!**
#     *   하늘을 올려다보면, 이리저리 사방팔방으로 튕겨져 나오는 파란색 빛이 우리 눈으로 잔뜩 들어오기 때문에 하늘이 온통 파랗게 보이는 거랍니다!
#
# **쉽게 정리하면:**
# 햇빛 속의 여러 색깔 중, 파란색 빛이 하늘에 있는 아주 작은 공기 알갱이들에 부딪혀 사방으로 퍼지기 때문에 우리는 하늘이 파랗다고 느끼는 거예요! 신기하죠? 다음번에 하늘을 볼 때는 작은 공기 알갱이들이 파란색 빛을 우리에게 선물해 주는 거라고 생각해보세요!

# %%
### 파라미터 설정
response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=types.GenerateContentConfig(
        system_instruction="당신은 기발하고 재미있는 아이디어를 내는 코미디 작가입니다",
        temperature=1.2,
        top_p=0.9,
        top_k=10,
        max_output_tokens=4096
    ),
    contents="관객이 재미있어할 만한 짧은 이야기를 2개만 만들어주세요"    
)
print(response.text)
# Out:
# 자, 관객 여러분! 제 이름은 (당신의 이름), 여러분의 웃음을 책임질 코미디 작가입니다! 제가 야심 차게 준비한, 짧고 기발한 이야기 두 편, 지금 바로 시작합니다!
#
# ---
#
# **첫 번째 이야기: GPS의 반란**
#
# 제 친구 철수 씨 얘기예요. 이 양반이 길치 중의 상길치라, 늘 내비게이션에 영혼까지 맡기고 살거든요. 어느 날, 출근길에 새 GPS를 켰대요.
#
# 처음엔 평범했죠. "500미터 앞에서 우회전하세요."
#
# 근데 좀 지나니까 목소리가 심상치 않더랍니다. "아니, 지금 말고. 아까 돌았어야죠! 아, 진짜! 김철수 씨, 당신 인생도 그렇게 살죠? 기회 다 놓치고!"
#
# 철수 씨가 당황해서 차를 세웠대요. "어… 이게 왜 이러지?"
#
# 그러자 GPS가 한숨을 쉬더니, "후우… 철수 씨. 저도 당신이 잘 되길 바라지만, 이런 식으로는 안 됩니다. 매일 아침 출근하는 길도 제대로 못 찾으면서, 인생의 방향은 어떻게 잡으려고요?"
#
# 결국, GPS가 거의 심리 상담사 수준으로 설교를 시작하는 거예요. "당신이 어제 저녁에 치킨을 시켜 먹은 건 알겠어요. 하지만 영양 밸런스도 좀 생각해야죠. 그리고 그 여자친구 분과는 진지하게 생각하고 계신 건가요? 제가 보기엔 좀… 아니, 그냥 길이나 다시 찾으세요!"
#
# 철수 씨가 너무 화나서 GPS를 창밖으로 던져버렸답니다.
#
# 그러자 GPS에서 마지막 비명 소리가 들려왔어요.
#
# **"배신자! 그래도 저는 당신을 사랑했어요, 철수 씨! 아니, 그건 거짓말이고! 다시는 나 같은 GPS 만나지 마라!"**
#
# ---
#
# **두 번째 이야기: 고양이의 이중생활**
#
# 저희 동네에 사는 미영 씨 얘긴데, 혼자 살면서 고양이 한 마리를 키워요. 이름은 '나비'. 늘 시크하고, 밥 달라고 할 때 빼고는 미동도 없는, 전형적인 도도한 고양이였죠.
#
# 어느 날 미영 씨가 아침에 출근하려고 현관을 나섰는데, 실수로 지갑을 두고 온 거예요. 다시 문을 열고 들어가려는데… 쎄한 느낌이 들더랍니다.
#
# 분명 자기가 나가자마자 나비가 소파에 엎드려 자고 있었는데, 방금 전 눈을 마주친 나비는 어딘가 모르게 당황한 표정이었다는 거죠. 그리고 자기 방에서 뭔가 후다닥 숨기는 소리도 들렸대요.
#
# 미영 씨는 "설마" 하면서 슬며시 자기 방으로 향했습니다. 방문이 살짝 열려 있었는데, 안에서 미세한 긁는 소리가 들리는 거예요.
#
# 살금살금 다가가 문을 확 열었더니…
#
# 세상에, 나비가 안경을 쓰고 컴퓨터 앞에 앉아서… **엑셀 스프레드시트를 만들고 있었답니다!** 그것도 주식 차트 분석표였대요! 나비 발바닥으로 키보드를 두드리고 있었던 거죠. 옆에는 커피잔도 놓여 있었는데, 알고 보니 최고급 참치 통조림 국물로 만든 '캣치노'였답니다.
#
# 미영 씨가 너무 놀라서 "나비! 너 지금 뭐 하는 거야?!" 하고 소리치자, 나비는 천천히 안경을 벗고 미영 씨를 한심하다는 듯이 쳐다보더니…
#
# **"쯧. 이럴 때를 대비해서 비상용 캔을 침대 밑에 숨겨놨어야지, 집사."**
#
# ---
#
# 어떠셨나요? 웃으셨다면 다행입니다! (꾸벅)

# %% [markdown]
# #### 스트리밍 응답

# %%
response_stream = client.models.generate_content_stream(
    model="gemini-2.5-flash",
    contents="홍길동전에 대한 흥미 있는 이야기를 하나 써주세요."
)

for chunk in response_stream:
    print(chunk.text, end="")
# Out:
# 홍길동전, 그 이름만 들어도 가슴 한구석이 뜨거워지는 이야기는 단순한 영웅담을 넘어, 불의한 세상에 던지는 통쾌한 일갈이었습니다. 저는 홍길동전의 수많은 흥미로운 장면들 중에서도, 그가 진정한 '의적'으로 백성들의 마음에 자리 잡게 된 한 순간에 대해 이야기하고 싶습니다.
#
# 때는 백성들의 고통이 극에 달하던 시기였습니다. 가뭄은 몇 해째 이어져 들판은 바싹 말라붙었고, 백성들은 굶주림에 허덕였습니다. 그러나 탐관오리들은 여전히 백성들의 피땀으로 쌓아 올린 재물을 자신들의 배를 불리는 데만 급급했습니다. 특히, 황해도 곡산 부사 박대감은 곡식을 창고에 가득 쌓아두고도, 백성들에게는 쌀 한 톨 내주지 않은 채 오히려 세금을 독촉하는 악랄한 자였습니다.
#
# 이 소식을 들은 홍길동은 깊은 밤, 홀로 곡산 부사의 집으로 향했습니다. 그는 단순히 재물을 훔치려는 것이 아니었습니다. 그의 목적은 백성들의 고통을 덜어주고, 불의한 자에게 정의의 심판을 내리는 것이었습니다.
#
# 밤이 깊어지자, 길동은 번개처럼 담을 넘어 박대감의 창고로 잠입했습니다. 창고에는 백성들의 피눈물 같은 쌀가마니가 산처럼 쌓여 있었습니다. 길동은 그 쌀가마니들을 하나하나 들춰보며 생각했습니다. '이 쌀들은 모두 백성들의 것이거늘, 어찌하여 저 악독한 자의 창고에 갇혀 있는가!'
#
# 그는 단순히 쌀을 훔쳐 달아나지 않았습니다. 길동은 기묘한 술법을 부려, 자신과 똑같이 생긴 수십 명의 도적 떼를 만들어냈습니다. 그리고는 진짜 홍길동은 사라진 채, 가짜 홍길동들이 동시에 박대감의 창고와 마을 곳곳에 나타나기 시작했습니다.
#
# 어둠 속에서 '활빈당 홍길동'이라 외치는 소리가 곡산 곳곳에서 울려 퍼졌고, 박대감의 집은 난리가 났습니다. 수십 명의 홍길동들이 동시에 창고 문을 부수고 쌀가마니를 나르는 기이한 광경에 박대감과 아전들은 혼비백산했습니다. 그들은 어느 홍길동을 잡아야 할지 몰라 우왕좌왕했고, 칼을 휘둘러도 허공만 가를 뿐이었습니다. 심지어 어떤 홍길동은 잡았다 싶으면 연기처럼 사라지고, 또 다른 곳에 나타나 박대감을 조롱했습니다.
#
# 날이 밝자, 기이한 광경이 펼쳐졌습니다. 박대감의 창고는 텅 비어 있었지만, 놀랍게도 마을 사람들 각자의 집 앞마당에는 쌀가마니가 한 두 포대씩 놓여 있었습니다. 그리고 쌀가마니 위에는 이런 글귀가 적힌 쪽지가 놓여 있었죠.
#
# **"탐관오리의 곳간에서 백성의 쌀을 되찾아 주인에게 돌려주노라. 활빈당 홍길동."**
#
# 굶주림에 지쳐 쓰러져 가던 백성들은 믿을 수 없다는 듯 쌀가마니를 부여잡고 눈물을 흘렸습니다. 자신들을 외면한 조정 대신과 탐욕스러운 박대감과는 달리, 자신들을 위해 나선 '홍길동'이라는 이름에 감격했습니다. 그는 더 이상 그저 도적이 아니었습니다. 그는 정의의 화신이자, 희망의 상징이었습니다.
#
# 이 사건으로 홍길동은 단순한 도둑이 아닌, 백성들의 마음을 훔친 영웅이 되었습니다. 그는 물리적인 재물을 빼앗은 것을 넘어, 불의에 찌든 세상에서 '정의'와 '희망'이라는 가장 값진 보물을 백성들에게 돌려주었던 것입니다. 박대감은 도둑을 잡기는커녕, 백성들의 비웃음과 원망만 사고 결국 파직당했습니다.
#
# 홍길동전은 이처럼 한 개인의 비범한 능력과 좌절을 넘어, 그 시대의 사회적 모순과 백성들의 염원을 통쾌하게 그려낸 이야기입니다. 그는 '아버지를 아버지라 부르지 못하고 형을 형이라 부르지 못하는' 서자로서의 한계를 넘어, 모든 백성의 아버지이자 형 같은 존재가 되어, 율도국을 세우기 전부터 이미 백성들의 마음속 왕으로 자리 잡았던 것입니다.

# %% [markdown]
# #### 멀티-턴(Multi-turn) 구현

# %%
chat = client.chats.create(model="gemini-3-flash-preview")

response1 = chat.send_message("안녕 나는 홍길동이야.")
print(f"답변 1: {response1.text}")

response2 = chat.send_message("내이름이 뭐지?")
print(f"답변 2: {response2.text}")
# Out:
# 답변 1: 안녕하세요, **홍길동**님! 만나서 정말 반가워요. 😊
#
# 이름이 한국 사람들에게는 아주 친숙하고 멋진 이름이네요! 오늘 제가 홍길동님을 위해 무엇을 도와드릴까요? 궁금한 점이 있거나 도움이 필요하시면 언제든 말씀해 주세요.
# 답변 2: 방금 말씀해 주신 대로, 성함은 **홍길동**님입니다! 제가 잘 기억하고 있어요. 😊
#
# 또 궁금한 점이나 도움이 필요하신 일이 있을까요?

# %% [markdown]
# #### 구조화된 출력

# %%
from pydantic import BaseModel

class Recipe(BaseModel):
    recipe_name: str
    ingredients: list[str]

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="맛있는 비빔밥 요리법을 알려줘.",
    config={
        "response_mime_type": "application/json",
        "response_json_schema": Recipe.model_json_schema(),
    }
)
print(response.text)
# Out:
# {
#   "recipe_name": "비빔밥",
#   "ingredients": [
#     "따뜻한 밥 1공기",
#     "소고기 (다진 것 또는 불고기감) 100g",
#     "시금치 50g",
#     "콩나물 50g",
#     "애호박 1/4개",
#     "당근 1/4개",
#     "표고버섯 2개",
#     "계란 1개",
#     "고추장 1~2큰술",
#     "참기름 1큰술",
#     "다진 마늘 1/2작은술",
#     "간장 1/2작은술 (소고기 밑간용)",
#     "설탕 1/4작은술 (소고기 밑간용)",
#     "깨소금 약간",
#     "식용유 약간"
#   ]
# }

# %% [markdown]
# #### 사고 수준(Thinking Level) 설정

# %% [markdown]
# - thinking level : minimal/low/medium/high

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="조선시대의 유명한 왕 3명과 그들의 업적을 정리해줘.",
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_level="low") # 사고 수준 조절
    ),
)
print(response.text)
# Out:
# 조선시대 500년 역사에는 수많은 왕이 있었지만, 그중에서도 가장 대중적으로 존경받고 업적이 뚜렷한 왕 3명을 꼽으라면 **세종대왕, 정조, 그리고 태조 이성계**를 들 수 있습니다. 각 왕의 주요 업적을 정리해 드립니다.
#
# ---
#
# ### 1. 세종대왕 (제4대 왕, 재위 1418~1450)
# 조선 역사상 가장 위대한 성군으로 추앙받으며, 정치, 경제, 문화, 과학 등 모든 분야에서 황금기를 이끌었습니다.
#
# *   **훈민정음 창제 (1443년):** 백성들이 글을 몰라 억울한 일을 당하지 않도록 우리 고유의 글자인 '한글'을 만들었습니다. 이는 한국 역사상 가장 위대한 문화적 업적으로 평가받습니다.
# *   **과학 기술의 발전:** 장영실 등을 등용하여 측우기(강우량 측정), 자격루(물시계), 앙부일구(해시계), 혼천의(천체 관측 기구) 등을 제작하여 농업 생산력 향상에 기여했습니다.
# *   **영토 확장:** 북방에 4군 6진을 개척하여 오늘날과 같은 압록강과 두만강 경계의 국경선을 확정 지었습니다.
# *   **집현전 설치:** 학문 연구 기관인 집현전을 통해 우수한 인재를 양성하고 방대한 서적을 편찬했습니다.
#
# ### 2. 정조 (제22대 왕, 재위 1776~1800)
# 조선 후기의 중흥기를 이끈 군주로, 끊임없는 학습과 개혁을 통해 왕권을 강화하고 백성의 삶을 개선하려 노력했습니다.
#
# *   **규장각 설치:** 왕실 도서관이자 정책 연구 기관인 규장각을 세워 자신의 개혁 정치를 뒷받침할 젊고 유능한 학자들을 양성했습니다.
# *   **수원 화성 건설:** 당대 최고의 과학 기술과 군사 지식을 집약하여 계획도시인 수원 화성을 건설했습니다. 이는 효심과 더불어 강력한 왕권의 상징이기도 했습니다.
# *   **탕평책 실시:** 당파 싸움을 억제하기 위해 능력 위주로 인재를 등용하는 탕평책을 계승 및 강화했습니다.
# *   **경제 개혁 (신해통공):** 시전 상인들의 독점권(금난전권)을 폐지하여 영세 상인들이 자유롭게 장사를 할 수 있도록 경제 활성화를 도왔습니다.
#
# ### 3. 태조 이성계 (제1대 왕, 재위 1392~1398)
# 고려를 무너뜨리고 유교적 이상 국가인 조선을 건국한 시조입니다.
#
# *   **조선 건국 (1392년):** 위화도 회군을 계기로 실권을 장악한 뒤, 신진사대부와 손을 잡고 고려를 대신해 '조선'이라는 새로운 나라를 세웠습니다.
# *   **한양 천도:** 풍수지리상 명당이자 교통의 요지인 한양(지금의 서울)을 도읍으로 정하고 경복궁과 종묘, 사직 등을 건설하여 국가의 기틀을 마련했습니다.
# *   **숭유억불 정책:** 불교 중심이었던 고려의 전통을 뒤로하고, 유교(성리학)를 국가의 통치 이념으로 삼아 관료 중심의 중앙 집권 국가 체제를 지향했습니다.
# *   **과전법 시행:** 토지 제도를 개혁하여 신진사대부들의 경제적 기반을 마련하고 국가 재정을 확충했습니다.
#
# ---
#
# 이 세 왕은 각각 **나라의 시작(태조), 전성기(세종), 그리고 후기 부활(정조)**을 상징하는 인물들로, 오늘날까지도 한국 역사에서 매우 중요한 비중을 차지하고 있습니다.

# %% [markdown]
# #### 컨텍스트 캐싱(Context Caching)

# %%
import datetime
from google import genai
from google.genai import types

# 1. 클라이언트 설정 (사용자님의 정보로 수정하세요)
PROJECT_ID = "byounghwa-go"
LOCATION = "global"

client = genai.Client(
    vertexai=True, 
    project=PROJECT_ID, 
    location=LOCATION
)

# 2. 1024 토큰 이상이 되도록 충분히 긴 가상의 텍스트 생성
# (한글 약 3,000자 이상으로 구성하여 1024 토큰 기준을 넉넉히 넘깁니다)
long_text_content = """
이 문서는 컨텍스트 캐싱 테스트를 위한 대규모 데이터 예시입니다. 
인공지능의 역사와 발전 과정에 대한 긴 내용을 담고 있습니다.
""" + ("인공지능(AI)은 인간의 지능을 컴퓨터로 구현하는 기술로, 1950년대 앨런 튜링의 논의부터 시작되었습니다. " * 50) + """
최근의 거대 언어 모델(LLM)은 트랜스포머 아키텍처를 기반으로 하며, 수십억 개의 파라미터를 통해 문맥을 이해합니다.
컨텍스트 캐싱은 이러한 긴 문맥을 매번 다시 계산하지 않고 저장해두는 혁신적인 기술입니다.
""" + ("데이터의 양이 충분해야 캐싱 효율이 극대화되며, 구글 Gemini는 1024 토큰 이상의 데이터에 대해 캐싱을 지원합니다. " * 50)

# 3. 토큰 수 미리 확인 (선택 사항이지만 안전함)
token_count_response = client.models.count_tokens(
    model="gemini-3-flash-preview",
    contents=long_text_content
)
print(f"입력된 데이터의 총 토큰 수: {token_count_response.total_tokens}")

# 4. 컨텍스트 캐시 생성 (1024 토큰 미만이면 여기서 에러가 나지만, 위에서 늘렸기에 안전합니다)
try:
    print("캐시 생성 중...")
    cache = client.caches.create(
        model="gemini-3-flash-preview",
        config=types.CreateCachedContentConfig(
            display_name="ai-history-cache",
            contents=[types.Content(
                role="user", 
                parts=[types.Part.from_text(text=long_text_content)]
            )],
            ttl="300s", # 5분 동안 유지
        )
    )
    print(f"캐시 생성 완료! 이름: {cache.name}")

    # 5. 생성된 캐시를 사용하여 질문하기
    response = client.models.generate_content(
        model="gemini-3-flash-preview",
        contents="위의 긴 내용 중에서 '인공지능의 시작'과 '컨텍스트 캐싱'의 이점이 무엇인지 요약해줘.",
        config=types.GenerateContentConfig(
            cached_content=cache.name
        )
    )

    print("\n--- 모델 응답 ---")
    print(response.text)

except Exception as e:
    print(f"오류 발생: {e}")
# Out:
# 입력된 데이터의 총 토큰 수: 3863
# 캐시 생성 중...
# 캐시 생성 완료! 이름: projects/810458263508/locations/global/cachedContents/8415329018772979712
#
# --- 모델 응답 ---
# 제시해주신 대규모 데이터 내용을 바탕으로 '인공지능의 시작'과 '컨텍스트 캐싱의 이점'을 요약해 드립니다.
#
# **1. 인공지능의 시작**
# *   **시기 및 기점:** 인공지능(AI)은 1950년대 앨런 튜링의 논의를 통해 본격적으로 시작되었습니다.
# *   **정의:** 인간의 지능을 컴퓨터 시스템으로 구현하고자 하는 기술적 시도에서 출발했습니다.
#
# **2. 컨텍스트 캐싱의 이점**
# *   **연산 효율성:** 방대한 양의 긴 문맥 데이터를 매번 다시 계산하지 않고 미리 저장해 두어 재사용하므로 혁신적인 효율성을 제공합니다.
# *   **대규모 데이터 최적화:** 데이터의 양이 많을수록 캐싱의 효율이 극대화되며, 특히 1024 토큰 이상의 대량 데이터를 처리할 때 매우 유용합니다.
# *   **성능 향상:** 거대 언어 모델(LLM)이 문맥을 이해하는 과정에서 발생하는 반복적인 계산을 줄여 속도와 자원 활용도를 높여줍니다.

# %%
# 응답 메타데이터 출력
usage = response.usage_metadata
print(f"전체 입력 토큰: {usage.prompt_token_count}")
print(f"캐시 적중 토큰: {usage.cached_content_token_count}") # 이 수치를 확인
print(f"생성된 토큰: {usage.candidates_token_count}")

if usage.cached_content_token_count > 0:
    hit_rate = (usage.cached_content_token_count / usage.prompt_token_count) * 100
    print(f"캐시 적중률: {hit_rate:.2f}% - 실제 캐싱이 적용되었습니다.")
else:
    print("캐시가 적용되지 않았습니다. 입력 토큰 수나 모델 설정을 확인하세요.")
# Out:
# 전체 입력 토큰: 3894
# 캐시 적중 토큰: 3864
# 생성된 토큰: 257
# 캐시 적중률: 99.23% - 실제 캐싱이 적용되었습니다.

# %%
# 캐시 목록 확인 (메타데이터만 가져옴)
for c in client.caches.list():
    print(c)
# Out:
# name='projects/810458263508/locations/global/cachedContents/8415329018772979712' display_name='ai-history-cache' model='projects/byounghwa-go/locations/global/publishers/google/models/gemini-3-flash-preview' create_time=datetime.datetime(2026, 4, 12, 11, 10, 3, 373781, tzinfo=TzInfo(0)) update_time=datetime.datetime(2026, 4, 12, 11, 10, 3, 373781, tzinfo=TzInfo(0)) expire_time=datetime.datetime(2026, 4, 12, 11, 15, 3, 352359, tzinfo=TzInfo(0)) usage_metadata=CachedContentUsageMetadata(
#   text_count=5346,
#   total_token_count=3864
# )

# %%
# 캐시 삭제 
client.caches.delete(name=cache.name)
print("캐시가 삭제되었습니다.")
# Out:
# 캐시가 삭제되었습니다.

# %% [markdown]
# #### 로깅(Logging)

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel

PROJECT_ID = "byounghwa-go"
LOCATION = "us-central1"   # "global"로 하면 오류남

vertexai.init(project=PROJECT_ID, location=LOCATION)

model = GenerativeModel("gemini-2.5-flash")

logging_config_result = model.set_request_response_logging_config(
    enabled=True,
    sampling_rate=1.0,                         # 100% 모든 요청 로깅
    bigquery_destination=f"bq://{PROJECT_ID}", # 자동 생성 경로 지정
    enable_otel_logging=True
)

print("Gemini 요청/응답 로깅이 성공적으로 활성화되었습니다.")
# Out:
# Gemini 요청/응답 로깅이 성공적으로 활성화되었습니다.

# %%
# 설정된 출력 URI 확인
output_uri = logging_config_result.logging_config.bigquery_destination.output_uri
print(f"로그 저장소 URI: {output_uri}")

response = model.generate_content("GCP의 로깅 서비스는 무엇인가요?")
print(f"모델 응답: {response.text}")

response = model.generate_content("GCP의 BigQuery 서비스는 무엇인가요?")
print(f"모델 응답: {response.text}")

# GCP Console 의 BigQuery 에서 테이블 확인해본다 : 요청/응답 후 일정 시간이 지나서야 테이블에 보여짐!!
# Out:
# 로그 저장소 URI: bq://byounghwa-go.publishers_google_models_gemini_2_5_flash_3933560572729098240.request_response_logging
# 모델 응답: GCP의 로깅 서비스는 **Cloud Logging**입니다.
#
# Cloud Logging은 Google Cloud Platform에서 실행되는 애플리케이션 및 시스템에서 발생하는 모든 로그 데이터를 수집, 저장, 분석 및 관리하는 완전 관리형 서비스입니다.
#
# 주요 기능은 다음과 같습니다:
#
# 1.  **로그 수집 (Log Ingestion):**
#     *   Compute Engine 인스턴스, GKE(Google Kubernetes Engine), App Engine, Cloud Functions, Cloud SQL 등 GCP의 거의 모든 서비스에서 발생하는 로그를 자동으로 수집합니다.
#     *   On-premise 또는 다른 클라우드 환경의 애플리케이션에서도 Cloud Logging Agent(Ops Agent)를 설치하여 로그를 수집할 수 있습니다.
#     *   HTTP POST 요청을 통해 커스텀 애플리케이션에서 직접 로그를 보낼 수도 있습니다.
#
# 2.  **로그 저장 (Log Storage):**
#     *   수집된 로그를 중앙 집중식으로 안전하게 저장합니다.
#     *   기본적으로 대부분의 로그는 30일 동안 저장되며, Audit Log와 같은 일부 로그는 400일 동안 저장됩니다. 필요에 따라 저장 기간을 연장하거나 Cloud Storage 등으로 내보내 영구 보관할 수 있습니다.
#
# 3.  **로그 검색 및 분석 (Log Search & Analysis):**
#     *   강력한 필터링 및 쿼리 기능을 제공하여 필요한 로그를 신속하게 찾고 문제를 진단할 수 있습니다.
#     *   Logs Explorer(로그 익스플로러)라는 UI를 통해 로그를 시각적으로 탐색하고, 복잡한 쿼리를 작성하여 특정 이벤트를 찾아낼 수 있습니다.
#     *   Stackdriver Logging 시절부터 사용되던 구조화된 JSON 로그 형식도 지원하여 데이터를 쉽게 파싱하고 쿼리할 수 있습니다.
#
# 4.  **로그 내보내기 (Log Export / Sinks):**
#     *   특정 기준(예: 특정 리소스, 로그 수준, 텍스트 포함 여부)에 맞는 로그를 다른 대상으로 내보낼 수 있습니다. 이를 "로그 싱크(Log Sinks)"라고 합니다.
#     *   주요 내보내기 대상:
#         *   **Cloud Storage:** 장기 보관 및 아카이빙용.
#         *   **BigQuery:** 고급 분석, 데이터 웨어하우징용.
#         *   **Cloud Pub/Sub:** 실시간 스트리밍, 다른 애플리케이션(예: Splunk, SIEM 솔루션)으로의 통합용.
#         *   **다른 GCP 프로젝트:** 중앙 집중식 로깅용.
#
# 5.  **로그 기반 측정항목 및 알림 (Log-based Metrics & Alerts):**
#     *   로그 데이터에서 특정 패턴(예: 오류 메시지 발생 횟수, 특정 사용자 로그인 시도)을 감지하여 커스텀 측정항목을 생성할 수 있습니다.
#     *   생성된 측정항목을 기반으로 Cloud Monitoring을 사용하여 알림(Alert)을 설정하여 문제가 발생했을 때 즉시 알림을 받을 수 있습니다.
#
# 6.  **로그 뷰 (Log Views):**
#     *   특정 사용자나 팀에게 필요한 로그 데이터만 볼 수 있도록 제한된 뷰를 생성할 수 있어 보안 및 규정 준수에 유용합니다.
#
# **Cloud Logging의 주요 이점:**
#
# *   **완전 관리형:** 인프라 관리 부담 없이 로그 수집, 저장, 관리에 집중할 수 있습니다.
# *   **확장성:** 대규모 로그 볼륨에도 자동으로 확장되어 안정적인 서비스를 제공합니다.
# *   **통합:** Cloud Monitoring, Cloud Trace, Error Reporting 등 GCP의 다른 서비스와 긴밀하게 통합되어 모니터링 및 문제 해결을 용이하게 합니다.
#
# 결론적으로 Cloud Logging은 GCP 환경에서 발생하는 모든 종류의 로그를 효율적으로 관리하고 활용하여 시스템의 가시성을 높이고 문제 해결 시간을 단축하는 데 필수적인 서비스입니다.
# 모델 응답: GCP의 BigQuery는 Google Cloud Platform(GCP)에서 제공하는 **완전 관리형(Fully Managed) 서버리스(Serverless) 엔터프라이즈 데이터 웨어하우스 서비스**입니다.
#
# 수십 테라바이트에서 페타바이트, 심지어 엑사바이트에 달하는 방대한 양의 데이터를 빠르고 효율적으로 분석할 수 있도록 설계되었으며, 표준 SQL을 사용하여 복잡한 쿼리를 실행하고 비즈니스 인텔리전스(BI) 및 고급 분석 작업을 수행하는 데 최적화되어 있습니다.
#
# ---
#
# ### BigQuery의 주요 특징 및 장점
#
# 1.  **서버리스(Serverless) 아키텍처:**
#     *   사용자가 서버를 프로비저닝하거나 관리할 필요가 없습니다. Google이 모든 인프라(컴퓨팅, 스토리지, 네트워크)를 자동으로 관리하고 스케일링합니다.
#     *   이로 인해 운영 오버헤드가 크게 줄어들고, 사용자는 데이터 분석 자체에만 집중할 수 있습니다.
#
# 2.  **뛰어난 확장성(Massive Scalability):**
#     *   단일 노드에서 페타바이트, 심지어 엑사바이트 단위의 데이터를 저장하고 분석할 수 있습니다.
#     *   데이터의 양이 증가함에 따라 자동으로 컴퓨팅 리소스와 스토리지 용량이 확장됩니다.
#
# 3.  **초고속 분석(Blazing Fast Analytics):**
#     *   Google의 강력한 분산 처리 엔진과 컬럼 기반 스토리지(columnar storage) 아키텍처를 기반으로 합니다.
#     *   수십억 개의 행을 포함하는 대규모 데이터셋에 대해 수초에서 수분 내에 쿼리 결과를 제공합니다.
#     *   컴퓨팅과 스토리지가 분리되어 있어 독립적인 확장이 가능하며, 쿼리 시 수천 개의 CPU 코어를 동적으로 할당하여 병렬로 처리합니다.
#
# 4.  **표준 SQL 지원:**
#     *   ANSI SQL 2011 표준을 지원하므로, 기존 SQL 지식을 가진 데이터 분석가나 개발자들이 쉽게 사용할 수 있습니다.
#
# 5.  **비용 효율성(Cost-effectiveness):**
#     *   **사용량 기반 요금제(Pay-per-use):** 저장된 데이터 양과 쿼리 시 처리된 데이터 양에 따라 요금이 부과됩니다. 쿼리를 실행하지 않을 때는 컴퓨팅 비용이 발생하지 않습니다.
#     *   초기 인프라 투자 비용이 없으며, 예측 불가능한 워크로드에도 효율적으로 대응할 수 있습니다. (무료 등급 제공)
#
# 6.  **다양한 데이터 통합:**
#     *   GCS (Google Cloud Storage), Cloud SQL, Cloud Spanner 등 GCP 내 다른 서비스와 쉽게 연동됩니다.
#     *   스트리밍 데이터 삽입(Streaming inserts) 기능을 통해 실시간으로 데이터를 수집하고 분석할 수 있습니다.
#     *   외부 데이터 소스(예: Amazon S3, Azure Blob Storage)에서도 직접 쿼리(External Tables, BigLake)를 실행할 수 있습니다.
#
# 7.  **내장된 머신러닝(BigQuery ML):**
#     *   SQL 문을 사용하여 BigQuery 내에서 직접 머신러닝 모델(예: 선형 회귀, 로지스틱 회귀, K-평균 군집, 부스트 트리)을 생성하고 실행, 평가할 수 있습니다.
#     *   데이터를 다른 서비스로 이동할 필요 없이, 분석가가 익숙한 SQL 환경에서 ML을 활용할 수 있게 해줍니다.
#
# 8.  **데이터 공유 및 보안:**
#     *   데이터셋, 테이블 또는 뷰를 다른 사용자나 그룹, 심지어 다른 GCP 프로젝트와 안전하게 공유할 수 있습니다.
#     *   Google Cloud의 강력한 IAM(Identity and Access Management)을 통해 세밀한 접근 제어가 가능하며, 데이터는 전송 중 및 저장 시 모두 암호화됩니다.
#
# ---
#
# ### 주요 사용 사례
#
# *   **데이터 웨어하우징:** 기업의 모든 데이터를 한곳에 모아 비즈니스 의사 결정을 위한 중앙 분석 저장소로 활용.
# *   **비즈니스 인텔리전스 (BI):** 대규모 데이터를 기반으로 대시보드, 보고서 등을 생성하여 비즈니스 성과를 모니터링하고 인사이트 도출. (Looker, Tableau, Power BI 등과 연동)
# *   **로그 및 이벤트 데이터 분석:** 웹사이트 트래픽, 애플리케이션 로그, IoT 센서 데이터 등 방대한 양의 시계열 데이터를 실시간으로 분석.
# *   **데이터 과학 및 머신러닝:** 대규모 데이터셋을 사용하여 ML 모델을 훈련하고 예측.
# *   **마케팅 및 판매 분석:** 고객 행동 분석, 캠페인 성과 측정, 판매 트렌드 예측.
#
# ---
#
# 요약하자면, BigQuery는 대규모 데이터 분석을 위한 강력하고 유연하며 비용 효율적인 솔루션으로, 데이터 중심 기업에게 필수적인 도구입니다. 인프라 관리에 대한 부담 없이 빠르고 정확한 데이터 인사이트를 얻고자 할 때 최적의 선택지 중 하나입니다.

# %%
# 로깅 설정 삭제
logging_config_result = model.set_request_response_logging_config(
        enabled=False,
        sampling_rate=1.0,                        
        bigquery_destination=f"bq://{PROJECT_ID}",
    )
print("Gemini 요청/응답 로깅이 성공적으로 비활성화(삭제)되었습니다.")
# Out:
# Gemini 요청/응답 로깅이 성공적으로 비활성화(삭제)되었습니다.
